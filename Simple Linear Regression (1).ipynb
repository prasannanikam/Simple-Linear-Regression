# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# %% [markdown]
# # 1) Delivery_time -> Predict delivery time using sorting time
# 2) Salary_hike -> Build a prediction model for Salary_hike
# Build a simple linear regression model by performing EDA and do necessary transformations and select the best model using R or Python.

# %% [markdown]
# 1) Delivery_time -> Predict delivery time using sorting time
# Build a simple linear regression model by performing EDA and do necessary transformations and select the best model using R or Python.

# %%
data=pd.read_csv("delivery_time.csv")
data.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
sns.distplot(data['Delivery Time'])
# Out:
# C:\Users\prasa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Delivery Time', ylabel='Density'>

# %%
sns.distplot(data['Sorting Time'])
# Out:
# C:\Users\prasa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sorting Time', ylabel='Density'>

# %%
data=data.rename({'Delivery Time':'dtime', 'Sorting Time':'stime'},axis=1)
data
# Out:
#     dtime  stime
# 0   21.00     10
# 1   13.50      4
# 2   19.75      6
# 3   24.00      9
# 4   29.00     10
# 5   15.35      6
# 6   19.00      7
# 7    9.50      3
# 8   17.90     10
# 9   18.75      9
# 10  19.83      8
# 11  10.75      4
# 12  16.68      7
# 13  11.50      3
# 14  12.03      3
# 15  14.88      4
# 16  13.75      6
# 17  18.11      7
# 18   8.00      2
# 19  17.83      7
# 20  21.50      5

# %%
#Correlation Analysis
data.corr()
# Out:
#           dtime     stime
# dtime  1.000000  0.825997
# stime  0.825997  1.000000

# %%
sns.regplot(x=data['stime'],y=data['dtime'])
# Out:
# <AxesSubplot:xlabel='stime', ylabel='dtime'>

# %%
#Model Building
model=smf.ols("dtime~stime",data=data).fit()

# %%
model.params
# Out:
# Intercept    6.582734
# stime        1.649020
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  dtime   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Sat, 01 Apr 2023   Prob (F-statistic):           3.98e-06
# Time:                        17:44:03   Log-Likelihood:                -51.357
# No. Observations:                  21   AIC:                             106.7
# Df Residuals:                      19   BIC:                             108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.5827      1.722      3.823      0.001       2.979      10.186
# ...

# %%
print(model.conf_int(0.05)) # 95% confidence interval
# Out:
#                   0          1
# Intercept  2.979134  10.186334
# stime      1.108673   2.189367

# %%
pred = model.predict(data) # Predicted values of dt using the model
pred
# Out:
# 0     23.072933
# 1     13.178814
# 2     16.476853
# 3     21.423913
# 4     23.072933
# 5     16.476853
# 6     18.125873
# 7     11.529794
# 8     23.072933
# 9     21.423913
# 10    19.774893
# 11    13.178814
# 12    18.125873
# 13    11.529794
# 14    11.529794
# 15    13.178814
# 16    16.476853
# 17    18.125873
# 18     9.880774
# 19    18.125873
# 20    14.827833
# dtype: float64

# %%
# Manual prediction for say sorting time 5
delivery_time = (6.582734) + (1.649020)*(5)
delivery_time
# Out:
# 14.827834

# %% [markdown]
# 2) Salary_hike -> Build a prediction model for Salary_hike Build a simple linear regression model by performing EDA and do necessary transformations and select the best model using R or Python.

# %%
sale=pd.read_csv("Salary_Data.csv")
sale.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
sns.distplot(sale['YearsExperience'])
# Out:
# C:\Users\prasa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsExperience', ylabel='Density'>

# %%
sns.distplot(sale['Salary'])
# Out:
# C:\Users\prasa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %%
sale.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.regplot(x=sale['YearsExperience'],y=sale['Salary'])
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
#Model Building
model=smf.ols("Salary~YearsExperience",data=sale).fit()

# %%
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
# Finding Pvalues and tvalues
model.tvalues, model.pvalues
# Out:
# (Intercept          11.346940
#  YearsExperience    24.950094
#  dtype: float64,
#  Intercept          5.511950e-12
#  YearsExperience    1.143068e-20
#  dtype: float64)

# %%
#Model Prediction
pred = model.predict(sale) # Predicted values of dt using the model
pred
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
# Manual prediction for say 3 Years Experience
Salary = (25792.200199) + (9449.962321)*(3)
Salary
# Out:
# 54142.087162
